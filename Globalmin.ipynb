# %% [markdown]
# <a href="https://colab.research.google.com/github/YaminiKothapally/AI/blob/main/Globalmin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
x=np.random.uniform(-10,10)
eta=0.001
iter_max=200
iter=1
while iter<=iter_max:
  slope=4*x*x*x+6*x
  step_length=(-eta)*slope
  x=x+step_length
  iter=iter+1
  print("control variable = ",round(x))
  obj=((x*x*x*x)+(3*x*x)+10)
  print("the objective function : ",round(obj));
# Out:
# control variable =  6
# the objective function :  1302
# control variable =  5
# the objective function :  724
# control variable =  4
# the objective function :  476
# control variable =  4
# the objective function :  343
# control variable =  4
# the objective function :  262
# control variable =  4
# the objective function :  208
# control variable =  3
# the objective function :  171
# control variable =  3
# the objective function :  143
# control variable =  3
# the objective function :  123
# control variable =  3
# the objective function :  107
# control variable =  3
# the objective function :  94
# control variable =  3
# the objective function :  84
# control variable =  3
# the objective function :  75
# control variable =  3
# the objective function :  68
# control variable =  2
# the objective function :  63
# control variable =  2
# the objective function :  58
# control variable =  2
# the objective function :  53
# control variable =  2
# the objective function :  50
# control variable =  2
# the objective function :  46
# control variable =  2
# the objective function :  44
# control variable =  2
# the objective function :  41
# control variable =  2
# the objective function :  39
# control variable =  2
# the objective function :  37
# control variable =  2
# the objective function :  35
# control variable =  2
# the objective function :  34
# control variable =  2
# the objective function :  32
# control variable =  2
# the objective function :  31
# control variable =  2
# the objective function :  30
# control variable =  2
# the objective function :  29
# control variable =  2
# the objective function :  28
# control variable =  2
# the objective function :  27
# control variable =  2
# the objective function :  26
# control variable =  2
# the objective function :  25
# control variable =  2
# the objective function :  24
# control variable =  2
# the objective function :  24
# control variable =  2
# the objective function :  23
# control variable =  2
# the objective function :  22
# control variable =  2
# the objective function :  22
# control variable =  1
# the objective function :  21
# control variable =  1
# the objective function :  21
# control variable =  1
# the objective function :  20
# control variable =  1
# the objective function :  20
# control variable =  1
# the objective function :  20
# control variable =  1
# the objective function :  19
# control variable =  1
# the objective function :  19
# control variable =  1
# the objective function :  19
# control variable =  1
# the objective function :  18
# control variable =  1
# the objective function :  18
# control variable =  1
# the objective function :  18
# control variable =  1
# the objective function :  17
# control variable =  1
# the objective function :  17
# control variable =  1
# the objective function :  17
# control variable =  1
# the objective function :  17
# control variable =  1
# the objective function :  17
# control variable =  1
# the objective function :  16
# control variable =  1
# the objective function :  16
# control variable =  1
# the objective function :  16
# control variable =  1
# the objective function :  16
# control variable =  1
# the objective function :  16
# control variable =  1
# the objective function :  15
# control variable =  1
# the objective function :  15
# control variable =  1
# the objective function :  15
# control variable =  1
# the objective function :  15
# control variable =  1
# the objective function :  15
# control variable =  1
# the objective function :  15
# control variable =  1
# the objective function :  15
# control variable =  1
# the objective function :  14
# control variable =  1
# the objective function :  14
# control variable =  1
# the objective function :  14
# control variable =  1
# the objective function :  14
# control variable =  1
# the objective function :  14
# control variable =  1
# the objective function :  14
# control variable =  1
# the objective function :  14
# control variable =  1
# the objective function :  14
# control variable =  1
# the objective function :  14
# control variable =  1
# the objective function :  14
# control variable =  1
# the objective function :  13
# control variable =  1
# the objective function :  13
# control variable =  1
# the objective function :  13
# control variable =  1
# the objective function :  13
# control variable =  1
# the objective function :  13
# control variable =  1
# the objective function :  13
# control variable =  1
# the objective function :  13
# control variable =  1
# the objective function :  13
# control variable =  1
# the objective function :  13
# control variable =  1
# the objective function :  13
# control variable =  1
# the objective function :  13
# control variable =  1
# the objective function :  13
# control variable =  1
# the objective function :  13
# control variable =  1
# the objective function :  13
# control variable =  1
# the objective function :  13
# control variable =  1
# the objective function :  13
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  12
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  1
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  11
# control variable =  0
# the objective function :  10
# control variable =  0
# the objective function :  10
# control variable =  0
# the objective function :  10
# control variable =  0
# the objective function :  10
# control variable =  0
# the objective function :  10
# control variable =  0
# the objective function :  10
# control variable =  0
# the objective function :  10
# control variable =  0
# the objective function :  10
# control variable =  0
# the objective function :  10
# control variable =  0
# the objective function :  10
